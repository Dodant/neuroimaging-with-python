# %%
# !pip install nilearn
from nilearn.masking import compute_epi_mask
from nilearn.plotting import plot_roi
# Out:
# ...
#   Using cached nilearn-0.7.1-py3-none-any.whl (3.0 MB)
# ...
# C:\Users\82108\anaconda3\lib\site-packages\nilearn\datasets\__init__.py:87: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "

# %%
file = 'C:\\Users\\82108\\Desktop\\RawData\\DONE\\nifti\\PKR_T2(MRI)_T2_TSE_AX_20210501231748_801.nii'

mask_img = compute_epi_mask(file)
plot_roi(mask_img)

# %%
file = 'C:\\Users\\82108\\Desktop\\RawData\\DONE\\nifti\\PKR_T2(MRI)_REGIST.nii'

mask_img = compute_epi_mask(file)
plot_roi(mask_img)

# %%
file = 'C:\\Users\\82108\\Desktop\\RawData\\DONE\\nifti\\PKR_T2_REGIST_SMTH.nii'

mask_img = compute_epi_mask(file)
plot_roi(mask_img)
